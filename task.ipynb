# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\German\Desktop\Задание 5.0 2 версия.xlsx")

# %%
df
# Out:
#                 FIO      Месяц              Профессия  Разряд  \
# 0     Абрамов Е. Д. 2009-01-01                Уборщик       3
# 1     Абрамов Е. Д. 2009-02-01                Уборщик       3
# 2     Абрамов Е. Д. 2009-03-01                Уборщик       3
# 3     Абрамов Е. Д. 2009-04-01                Уборщик       3
# 4     Абрамов Е. Д. 2009-05-01                Уборщик       3
# ...             ...        ...                    ...     ...
# 2395  Яковлев Д. И. 2009-08-01  Подручный вальцовщика       4
# 2396  Яковлев Д. И. 2009-09-01  Подручный вальцовщика       4
# 2397  Яковлев Д. И. 2009-10-01  Подручный вальцовщика       4
# 2398  Яковлев Д. И. 2009-11-01  Подручный вальцовщика       4
# 2399  Яковлев Д. И. 2009-12-01  Подручный вальцовщика       4
#
#             Оборудование  Вредность (балл.)  Объем производства         Доход
# 0     Пилигримовые станы                 18                 580  16638.000000
# ...

# %%
sum(df['Доход'])
# Out:
# 51997369.36764712

# %%
df.groupby(['FIO']).sum()
# Out:
#                    Разряд  Вредность (балл.)  Объем производства  \
# FIO
# Абрамов Е. Д.          36                216               11860
# Абрамов Ф. М.          36                216               11860
# Агафонов С. И.         72                216               11860
# Аксенов Е. Н.          84                264               11860
# Александров А. М.      36                216               11860
# ...                   ...                ...                 ...
# Шестаков Е. А.         36                216               11860
# Щербаков А. Е.         48                 96               11860
# Щербаков А. М.         60                216               11860
# Щукин К. С.            60                 96               11860
# Яковлев Д. И.          48                216               11860
#
#                            Доход
# FIO
# Абрамов Е. Д.      216442.905882
# Абрамов Ф. М.      208371.864706
# Агафонов С. И.     290950.941176
# Аксенов Е. Н.      339879.882353
# ...
